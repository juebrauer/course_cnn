# %% [markdown]
# # Gültige Variablennamen in Python

# %%
a = 42

# %%
A = 43

# %%
print(a,A)
# Out:
# 42 43

# %%
filter = None

# %%
Filter * 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ff172aaee66b> in <module>()
# ----> 1 Filter * 2
#
# NameError: name 'Filter' is not defined

# %%
123a = 44
# Out:
#   File "<ipython-input-6-99158644871a>", line 1
#     123a = 44
#        ^
# SyntaxError: invalid syntax

# %%
a123 = 44

# %%
_a123 = 45

# %%
a_123_ = 46

# %%
__öäüß = 47

# %%
§123 = 48
# Out:
#   File "<ipython-input-10-738273884f04>", line 1
#     §123 = 48
#        ^
# SyntaxError: invalid character in identifier

# %%
á = 48

# %% [markdown]
# # Basisdatentypen

# %%
# In C oder C++:
# int a;
# a = 456;

a = 42

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-67e500defa1b> in <module>()
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
type(a)
# Out:
# int

# %%
a = 42.0

# %%
type(a)
# Out:
# float

# %%
a = "42"

# %%
type(a)
# Out:
# str

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
if a==0:
  print("a hat quasi den Wert 0")
else:
  print("a hat nicht den Wert 0")
# Out:
# a hat nicht den Wert 0

# %%
c = int(True)
c
# Out:
# 1

# %%
d = int(False)
d
# Out:
# 0

# %%
var1 = 3+4j

# %%
type(var1)
# Out:
# complex

# %%
var1**2
# Out:
# (-7+24j)

# %%
# if (a==1) || ((b==2) && (c==3)) {...}
a = 3
b = 2
c = 4
if (a==1) or ((b==2) and (c==3)):
  print("Test")

# %%
e = True

# %%
not e
# Out:
# False

# %% [markdown]
# # Spezielle Python-Operatoren

# %%
5 // 2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
2**3
# Out:
# 8

# %% [markdown]
# # Maximale Größe eines int in Python

# %%
import sys
sys.maxsize
# Out:
# 9223372036854775807

# %%
large_number = 4837483948934382**10000

# %%
large_number
# Out:
# ...

# %% [markdown]
# # Listen, Tupel und Dictionaries

# %%
l = [1,2,3,4,5]
t = (1,2,3,4,5)

# %%
type(l)
# Out:
# list

# %%
type(t)
# Out:
# tuple

# %%
l.append(6)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# listen: mutable
# tupel: immutable
t.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-d0908ae6cae4> in <module>()
# ----> 1 t.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
l[0] = 42
l
# Out:
# [42, 2, 3, 4, 5, 6]

# %%
t[0] = 42
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-718e8eb4134e> in <module>()
# ----> 1 t[0] = 42
#
# TypeError: 'tuple' object does not support item assignment

# %%
d = { "deutschland" : 80, "usa" : 300, "indien" : 1400 }

# %%
d
# Out:
# {'deutschland': 80, 'indien': 1400, 'usa': 300}

# %%
d["deutschland"]
# Out:
# 80

# %%
d["frankfreich"] = 60

# %%
d
# Out:
# {'deutschland': 80, 'frankfreich': 60, 'indien': 1400, 'usa': 300}

# %%
param = { "nr_layers": 7, "learn_rate": 0.1, "activation_func": "sigmoid" }
