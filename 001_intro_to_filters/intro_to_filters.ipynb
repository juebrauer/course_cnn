# %% [markdown]
# # Introduction
#
# In this notebook we will introduce image filters using simple examples.

# %% [markdown]
# # Check dependencies
#
# In the following some libraries are needed:

# %%
import cv2
print(cv2.__version__)

import matplotlib
print(matplotlib.__version__)
# Out:
# 4.2.0
# 3.1.3

# %% [markdown]
# # Load test image

# %%
fname = "pics/on_the_highway_a7.png"
img = cv2.imread(fname)

# %%
img.shape
# Out:
# (836, 1493, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# # Display the test image

# %%
import matplotlib.pyplot as plt

plt.imshow(img)

# %% [markdown]
# Ups! The colors are strange. Actually the sky should be blue!

# %% [markdown]
# # Convert from BGR to RGB color channel order

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %% [markdown]
# # Set display size

# %%
def show_image(img, pixel_size_in_inch=0.02):
    fig_height_inch = int(img.shape[0] * pixel_size_in_inch)
    fig_width_inch  = int(img.shape[1] * pixel_size_in_inch)
    plt.figure(figsize=(fig_height_inch,fig_width_inch))
    plt.imshow(img)
    
show_image(img)

# %% [markdown]
# # Show each color channel separately

# %%
pixel_size_in_inch = 0.015
fig_height_inch = int(img.shape[0] * pixel_size_in_inch)
fig_width_inch  = int(img.shape[1] * pixel_size_in_inch)

color_names = ["red", "green", "blue"]

for channel_nr in range(0,3):
    channel = img[:,:,channel_nr]
    print(channel.shape)

    plt.figure(figsize=(fig_height_inch,fig_width_inch))
    plt.title("Color channel: {0}".format(color_names[channel_nr]))
    plt.imshow(channel, cmap="gray")
    
    cb = plt.colorbar(shrink=0.3)
    cb.ax.tick_params(labelsize=10)
    
    plt.show()
# Out:
# (836, 1493)
# (836, 1493)
# (836, 1493)
